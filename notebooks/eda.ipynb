# %%
# This file is to EDA Exploratory Data Analysis, and to check the consistency of the data. It is not to be used for any other purpose.
# Gannnki, 2026.04.17

# %%
# imports and configs
# add root dir to path
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from src.DataLoader import DataLoader
from src.ConsistencyChecker import CSVConsistencyChecker
from pathlib import Path

BASE_DIR = Path().resolve().parent
DATA_DIR_INCIDENTS = BASE_DIR / "lfb_converted/incidents"
DATA_DIR_MOBILISATION = BASE_DIR / "lfb_converted/mobilisation"

# %%
import os
print(os.getcwd())
# Out:
# /home/yolanda/Desktop/PRJ_Github/mle_liora_london_firefighter/notebooks

# %%
incident_loader = DataLoader(DATA_DIR_INCIDENTS, loader_config=True)
incident_df = incident_loader.load_all_csv_in_folder()

mobilisation_loader = DataLoader(DATA_DIR_MOBILISATION, loader_config=True)
mobilisation_df = mobilisation_loader.load_all_csv_in_folder()

# print the infos of both dataframes
print("Incidents DataFrame info:")
#incident_df.info()

print("\nMobilisation DataFrame info:")
#mobilisation_df.info()
# Out:
# /home/yolanda/Desktop/PRJ_Github/mle_liora_london_firefighter/src/DataLoader.py:58: DtypeWarning: Columns (0: IncidentNumber) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /home/yolanda/Desktop/PRJ_Github/mle_liora_london_firefighter/src/DataLoader.py:58: DtypeWarning: Columns (0: IncidentNumber, 1: DateAndTimeReturned) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /home/yolanda/Desktop/PRJ_Github/mle_liora_london_firefighter/src/DataLoader.py:58: DtypeWarning: Columns (0: DateAndTimeReturned) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Incidents DataFrame info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1952560 entries, 0 to 1952559
# Data columns (total 40 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   IncidentNumber                          object
#  1   DateOfCall                              str
#  2   CalYear                                 int64
#  3   TimeOfCall                              str
#  4   HourOfCall                              int64
#  5   IncidentGroup                           str
#  6   StopCodeDescription                     str
#  7   SpecialServiceType                      str
#  8   PropertyCategory                        str
#  9   PropertyType                            str
#  10  AddressQualifier                        str
#  11  Postcode_full                           str
#  12  Postcode_district                       str
#  13  UPRN                                    float64
#  14  USRN                                    float64
#  15  IncGeo_BoroughCode                      str
#  16  IncGeo_BoroughName                      str
#  17  ProperCase                              str
#  18  IncGeo_WardCode                         str
#  19  IncGeo_WardName                         str
#  20  IncGeo_WardNameNew                      str
#  21  Easting_m                               float64
#  22  Northing_m                              float64
#  23  Easting_rounded                         int64
#  24  Northing_rounded                        int64
#  25  Latitude                                float64
#  26  Longitude                               float64
#  27  FRS                                     str
#  28  IncidentStationGround                   str
#  29  FirstPumpArriving_AttendanceTime        float64
#  30  FirstPumpArriving_DeployedFromStation   str
#  31  SecondPumpArriving_AttendanceTime       float64
#  32  SecondPumpArriving_DeployedFromStation  str
#  33  NumStationsWithPumpsAttending           float64
#  34  NumPumpsAttending                       float64
#  35  PumpCount                               int64
#  36  PumpMinutesRounded                      int64
#  37  Notional Cost (£)                       int64
#  38  NumCalls                                float64
#  39  source_file                             str
# dtypes: float64(11), int64(7), object(1), str(21)
# memory usage: 595.9+ MB
#
# Mobilisation DataFrame info:
# <class 'pandas.DataFrame'>
# RangeIndex: 2753920 entries, 0 to 2753919
# Data columns (total 25 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   IncidentNumber            object
#  1   CalYear                   int64
#  2   HourOfCall                int64
#  3   ResourceMobilisationId    int64
#  4   Resource_Code             str
#  5   PerformanceReporting      str
#  6   DateAndTimeMobilised      str
#  7   DateAndTimeMobile         str
#  8   DateAndTimeArrived        str
#  9   TurnoutTimeSeconds        float64
#  10  TravelTimeSeconds         float64
#  11  AttendanceTimeSeconds     int64
#  12  DateAndTimeLeft           str
#  13  DateAndTimeReturned       object
#  14  DeployedFromStation_Code  str
#  15  DeployedFromStation_Name  str
#  16  DeployedFromLocation      str
#  17  PumpOrder                 int64
#  18  PlusCode_Code             str
#  19  PlusCode_Description      str
#  20  DelayCodeId               float64
#  21  DelayCode_Description     str
#  22  source_file               str
#  23  BoroughName               str
#  24  WardName                  str
# dtypes: float64(3), int64(5), object(2), str(15)
# memory usage: 525.3+ MB
